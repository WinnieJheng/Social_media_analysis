# %%
import pandas as pd
from snownlp import SnowNLP
df = pd.read_csv("comments_cutted_cs.csv")

# %%
def get_sentiment_cn(text):
    s = SnowNLP(text)
    return s.sentiments
df["sentiment"] = df.評論.apply(get_sentiment_cn)

# %%
df
# Out:
#                                                     評論     sentiment
# 0    標題[遊記]花蓮旅遊-慕谷慕魚(超美的溪谷，享受天然的魚去腳皮)時間SatJun2512:2...  9.999793e-01
# 1    標題[遊記]花蓮統茂渡假莊園-安靜休息的好地方時間WedOct2613:54:242016第...  6.554039e-01
# 2    標題[遊記]入宿捕獲野生Duncan時間SatDec600:29:122014一直以來非常喜...  3.362286e-08
# 3    標題[食記]反推黃昏市場汗馬X斯時間TueAug2623:52:472014消費時間：201...  1.678477e-05
# 4    標題[遊記]民宿經驗靜巷裡的27號時間TueAug2817:34:532012民宿名稱：靜巷...  1.449304e-05
# 5    標題[食記]一品坊早餐，正當冰很多喵星人時間ThuNov1015:06:132016://i...  2.891894e-06
# 6    標題[遊記]9/5六十石山花況時間TueSep623:34:502016昨天早上上六十石山，...  2.584666e-11
# 7    標題[遊記]太魯閣燕子口步道時間TueMay2013:38:282014遊玩時間：2014年...  9.699465e-01
# 8    標題Fw:[食記]花蓮：品味金針花☆六十石山鐵掌櫃茶舍時間WedSep322:13:3320...  1.734835e-09
# 9    標題[食記]花蓮市區—花蓮市區—痣男｜賣滷肉飯、賣麵疙瘩的復古西服店時間ThuMar709:...  3.671530e-11
# 10   標題[食記]月之盧食堂梅子雞+來去秘密喝咖啡時間MonNov2715:24:302017消費...  1.269176e-04
# 11   標題[食記]花蓮市區—曾品麻辣臭豆腐｜又臭又香！一口咬下湯汁迸發時間WedFeb620:18...  4.685605e-08
# 12   標題[食記]花蓮市區—安娜咖啡｜高CP值下午茶不到百元的美味法式吐司時間SatMay414:...  9.400015e-01
# ...
